# %% [markdown]
# In this project I will be utilyzing AI to analyze a video of a soccer/football game and display varying information about the status of the game to the viewer

# %% [markdown]
# The first thing I want to do is inference a video of a socccer game with a yolo model and see how accurate it is and what kind of things need to be changed

# %% [markdown]
# Once it is inferenced i will look at the results and train a model so that it gets better readings
